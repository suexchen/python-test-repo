# %% [markdown]
# <a href="https://colab.research.google.com/github/suexchen/python-test-repo/blob/test_branch/Get_Snowflake_Connection_in_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### get snowflake connection in colab HELLO andrew was here

# %%
pip install snowflake-connector-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 26.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.6/194.6 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 21.5 MB/s eta 0:00:00
# ...

# %%
import getpass 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
pwd = getpass.getpass("Enter Password:")

# %%
import snowflake.connector
conn = snowflake.connector.connect(user = 'sue.c@roserocket.com', password = str(pwd), account = 'zibxkti-roserocket'
, role = "DEVELOPER", database =  "ANALYTICS_DEV", schema = "SUEC_PLG", warehouse = "DEVELOPER_XS")

# %%
sql = "select * from ANALYTICS_DEV.SUEC_PLG.ORG_EVENTS_TOTAL limit 10"

# %%
res = conn.cursor().execute(sql).fetchall()

# %%
df = pd.read_sql(sql, conn)
df.head()
# Out:
# <ipython-input-22-3f43c91db358>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql, conn)
#                                  ORG_ID                           NAME  \
# 0  e8e96ec7-7a3a-4a8f-b6b9-a4dcba007f45  MJS Ameritrans Logistics Inc.
# 1  fa438665-8144-4b89-b28d-c36a10a824d0                Kwest Logistics
# 2  e46b1bb9-28be-4128-9e4c-4b24b89af642             Goldlink Logistics
# 3  7bc84f81-ec5b-4126-9d00-9efac19b7fec       TWO POINTS LOGISTICS INC
# 4  57b33453-8504-482c-ac46-d87c9030c4f1        G-Freight Logistics Inc
#
#            PLAN                                  ALL_TAGS  \
# 0        custom                             Medium Broker
# 1        custom                             Medium Broker
# 2      freemium                           Freemium|Hybrid
# ...
